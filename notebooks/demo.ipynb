# %% [markdown]
# # Generative Models for Multimodal Accessibility — Demo
#
# End-to-end walkthrough: load a fine-tuned checkpoint, generate an accessible image variant, produce alt-text, and compute fairness metrics.

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path().resolve().parent / 'src'))
import torch

# %%
from models.diffusion import AccessibilityDiffusion, DiffusionConfig
cfg = DiffusionConfig()
model = AccessibilityDiffusion(cfg)
prompts = ['a photograph of a city street']
variant = torch.tensor([0])
img = model.sample(prompts, variant, steps=10)
print(img.shape)

# %%
from models.llm import AltTextLLM, LLMConfig
llm = AltTextLLM(LLMConfig(load_in_4bit=False))
print(sum(p.numel() for p in llm.parameters() if p.requires_grad), 'trainable params')

# %%
from evaluation.fairness import disparity_metrics
scores = [0.7]*20 + [0.6]*20
attrs = [('light','fem','adult')]*20 + [('dark','masc','adult')]*20
disparity_metrics(scores, attrs, ('skin_tone','gender_presentation','age_bucket'))
